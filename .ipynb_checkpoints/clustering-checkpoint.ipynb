# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
# %matplotlib inline

# %%
dfsource = pd.read_csv("dataForClustering_.csv")
df = dfsource.iloc[:,:-1]#all cols except bookname col 
df_names= dfsource.iloc[:,-1:]#bookname col
namelist = df_names.values.tolist()
namelist = [i[0] for i in namelist]#flatten
namelist
# Out:
# ['The winters tale',
#  'The terror',
#  'The island of doctor moreau',
#  'Magic of oz',
#  'Road to oz',
#  'Warlord of kor',
#  'Justice',
#  'Lady susan',
#  'The house of the vampire',
#  'The life and adventures of santa claus',
#  'Art and mortality',
#  'Tamburlaine the great part 1',
#  'The adventures of tom sawyer',
#  'Children of the frost']

# %% [markdown]
# ## Apply KMeans to generate clusters as new column

# %%
clusters = 3
kmeans = KMeans(n_clusters = clusters)
y_predicted = kmeans.fit_predict(df)
print(kmeans.labels_)
print(kmeans.inertia_)
# Out:
# [2 2 2 0 1 2 2 1 0 1 1 0 2 0]
# 0.7756758506586762

# %%
df["cluster"] = y_predicted
pd.set_option('display.max_rows', None)
df
# df.head()
# Out:
#       point1   point 2   point 3   point 4   point 5   point 6   point 7  \
# 0   5.278057  5.277073  5.297691  5.313920  5.302599  5.314356  5.335452
# 1   5.284671  5.308155  5.325166  5.350037  5.363998  5.350037  5.362518
# 2   5.325406  5.305446  5.282063  5.305312  5.334608  5.334563  5.329673
# 3   5.391304  5.408672  5.434074  5.468632  5.452328  5.405541  5.365784
# 4   5.315902  5.350974  5.355123  5.349717  5.350094  5.376618  5.404588
# 5   5.274326  5.257574  5.227907  5.227139  5.199567  5.196147  5.219042
# 6   5.310131  5.290306  5.293513  5.300073  5.307216  5.310204  5.326895
# 7   5.458411  5.450186  5.469429  5.466015  5.484792  5.507759  5.509156
# 8   5.446829  5.443509  5.447659  5.423533  5.416301  5.397451  5.366509
# 9   5.566900  5.566034  5.535864  5.486980  5.458142  5.442824  5.426840
# 10  5.374022  5.379784  5.370821  5.378005  5.358088  5.346991  5.363138
# 11  5.487801  5.461892  5.443232  5.405285  5.377651  5.349542  5.343717
# 12  5.301541  5.279666  5.260599  5.226333  5.173942  5.172666  5.189926
# 13  5.430962  5.427529  5.403664  5.354217  5.327975  5.264928  5.244265
#
#      point 8   point 9  point 10  point 11  point 12  point 13  point 14  \
# 0   5.335705  5.366351  5.368292  5.364832  5.362244  5.357617  5.347885
# 1   5.396265  5.388683  5.360022  5.314904  5.272467  5.257951  5.271820
# 2   5.351678  5.367593  5.366348  5.354612  5.293976  5.206890  5.155679
# 3   5.340383  5.319412  5.345759  5.312677  5.288221  5.273393  5.273984
# 4   5.408108  5.428787  5.421307  5.452797  5.520679  5.578190  5.591452
# 5   5.209828  5.202080  5.220578  5.191819  5.223370  5.236004  5.263437
# 6   5.344971  5.334548  5.319461  5.309767  5.304883  5.306633  5.283746
# 7   5.515829  5.526536  5.530726  5.539727  5.526071  5.509777  5.485568
# 12  5.301541  5.279666  5.260599  5.226333  5.173942  5.172666  5.189926
# 13  5.430962  5.427529  5.403664  5.354217  5.327975  5.264928  5.244265
#
#      point 8   point 9  point 10  ...  point 12  point 13  point 14  point 15  \
# 0   5.335705  5.366351  5.368292  ...  5.362244  5.357617  5.347885  5.322837
# 1   5.396265  5.388683  5.360022  ...  5.272467  5.257951  5.271820  5.254900
# 2   5.351678  5.367593  5.366348  ...  5.293976  5.206890  5.155679  5.128473
# 3   5.340383  5.319412  5.345759  ...  5.288221  5.273393  5.273984  5.273511
# 4   5.408108  5.428787  5.421307  ...  5.520679  5.578190  5.591452  5.583784
# 5   5.209828  5.202080  5.220578  ...  5.223370  5.236004  5.263437  5.270557
# 6   5.344971  5.334548  5.319461  ...  5.304883  5.306633  5.283746  5.273761
# 7   5.515829  5.526536  5.530726  ...  5.526071  5.509777  5.485568  5.493327
# 8   5.354060  5.318376  5.296562  ...  5.271962  5.266331  5.269472  5.286366
# 9   5.425641  5.416650  5.421712  ...  5.403596  5.411921  5.418848  5.433367
# 10  5.382629  5.434415  5.466923  ...  5.462370  5.468914  5.460378  5.447219
# 11  5.316794  5.321864  5.347018  ...  5.376680  5.359767  5.358386  5.344709
# 12  5.196760  5.240668  5.289720  ...  5.309730  5.311811  5.271301  5.292725
# 13  5.255686  5.274171  5.275590  ...  5.333983  5.328668  5.327348  5.306618
#
#     point 16  point 17  point 18  point 19  cluster  \
# 0   5.275399  5.292993  5.343905  5.378727        2
# 1   5.276072  5.278476  5.249815  5.240570        2
# 2   5.112825  5.094065  5.089131  5.103267        2
# 3   5.269553  5.295132  5.288221  5.301867        0
# 4   5.586235  5.589063  5.622879  5.642615        1
# 5   5.260924  5.262530  5.254572  5.266299        2
# 6   5.267857  5.266618  5.266983  5.262391        2
# 7   5.499224  5.474395  5.459497  5.478119        1
# 8   5.285951  5.290634  5.278305  5.268050        0
# 9   5.470263  5.492041  5.514352  5.524875        1
# 10  5.452198  5.467065  5.471831  5.469910        1
# 11  5.325467  5.309977  5.261784  5.221249        0
# 12  5.266038  5.298891  5.297811  5.322514        2
# 13  5.315927  5.306915  5.292491  5.292986        0
#
#                                  book name
# 0                         The winters tale
# 1                               The terror
# 2              The island of doctor moreau
# 3                              Magic of oz
# 4                               Road to oz
# 5                           Warlord of kor
# 6                                  Justice
# 7                               Lady susan
# 8                 The house of the vampire
# 9   The life and adventures of santa claus
# 10                       Art and mortality
# 11            Tamburlaine the great part 1
# 12            The adventures of tom sawyer
# 13                   Children of the frost
#
# [14 rows x 21 columns]

# %%
def transform(df):
    df = df.T
    df.reset_index(drop=True, inplace=True)
    return df

# %%
def plot_a_cluster(df,cluster_num):
    booknames = []
    data = transform(df)
    datalist =  data.values.tolist()
    datalist = np.array(datalist)
    numrows_data = len(datalist)
    booknames = df.iloc[-1].values.tolist()
    
    y = datalist[0][:-2]
    x = np.linspace(0,100,len(y))


    fig = plt.figure()
    ax = plt.subplot(111)
    ax.plot(x, y, label='%s'%booknames[0])
 
    if numrows_data>1:
        for i in range(1,numrows_data):
            next_y= datalist[i][:-2]
            ax.plot(x,next_y, label = "%s"%booknames[i])


    fmt = '%.0f%%' # Format you want the ticks, e.g. '40%'
    xticks = mtick.FormatStrFormatter(fmt)
    ax.xaxis.set_major_formatter(xticks)
    plt.yticks(np.arange(float(min(y)), float(max(y))+1, 0.5))


    fig.suptitle("graph of cluster %i"%cluster_num, fontsize = 20)
    plt.xlabel('percentage of document', fontsize=12)
    plt.ylabel('sentiment score', fontsize=12)

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    plt.show()

for i in range(clusters):
    df_i = df[df.cluster.isin([i])]
    df_i = transform(df_i)
    plot_a_cluster(df_i,i)
# Out:
# look at me ['5.391304347999999' '5.408672022999999' '5.434073724' '5.468631853'
#  '5.452327505' '5.405541115' '5.365784499' '5.340382798' '5.319411626'
#  '5.345758507' '5.312677221' '5.288220699' '5.273393195' '5.273983932'
#  '5.273511342' '5.269553403' '5.295132325' '5.288220699' '5.30186673']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-46017ecb6965> in <module>
#      44     df_i = df[df.cluster.isin([i])]
#      45     df_i = transform(df_i)
# ---> 46     plot_a_cluster(df_i,i)
#
# <ipython-input-49-46017ecb6965> in plot_a_cluster(df, cluster_num)
#      25     ax.xaxis.set_major_formatter(xticks)
#      26     print("look at me",y)
# ---> 27     plt.yticks(np.arange(min(y), max(y)+1, 0.5))
#      28
#      29
#
# TypeError: can only concatenate str (not "int") to str

# %%
# def plot_a_cluster(df,cluster_num):
#     data = transform(df)
#     datalist =  data.values.tolist()
#     firstrow_data = datalist[0][:-1]####################
#     numrows_data = len(datalist)
#     perc = np.linspace(0,100,len(firstrow_data))

#     fig = plt.figure()
#     ax = fig.add_subplot(1,1,1)

#     ax.plot(perc, firstrow_data)

#     if numrows_data>1:
#         for i in range(1,numrows_data):
#             nextrow_data = datalist[i][:-1]########
#             ax.plot(perc,nextrow_data)


#     fmt = '%.0f%%' # Format you want the ticks, e.g. '40%'
#     xticks = mtick.FormatStrFormatter(fmt)
#     ax.xaxis.set_major_formatter(xticks)
#     print("LOOK AT ME",y)
#     plt.yticks(np.arange(min(y), max(y)+1, 0.5))


#     fig.suptitle("graph of cluster %i"%cluster_num, fontsize = 20)
#     plt.xlabel('percentage of document', fontsize=12)
#     plt.ylabel('sentiment score', fontsize=12)

# for i in range(clusters):
#     df_i = df[df.cluster.isin([i])]
#     df_i = transform(df_i)
#     plot_a_cluster(df_i,i)
# Out:
# LOOK AT ME [0, 1, 2, 3, 4]
# LOOK AT ME [0, 1, 2, 3, 4]
# LOOK AT ME [0, 1, 2, 3, 4]

# %%
x = [0,5,9,10,15]

y = [0,1,2,3,4]

plt.plot(x,y)

plt.yticks(np.arange(min(y), max(y)+1, 1.0))

plt.show()
